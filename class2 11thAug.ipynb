# %%
from sympy import *

# %%
x=Symbol('x')

# %%
expr=exp(x)

# %%
expr.diff(x)
# Out:
# exp(x)

# %%
expr=exp(-x**2)

# %%
expr.diff(x)
# Out:
# -2*x*exp(-x**2)

# %%
integrate(expr,x)
# Out:
# sqrt(pi)*erf(x)/2

# %%
k=Symbol('k')

# %%
omega=Symbol('omega')

# %%
expr=exp(k*x)*cos(omega*x)

# %%
integrate(expr,x)
# Out:
# Piecewise((x, Eq(k, 0) & Eq(omega, 0)), (I*x*exp(-I*omega*x)*sin(omega*x)/2 + x*exp(-I*omega*x)*cos(omega*x)/2 + exp(-I*omega*x)*sin(omega*x)/(2*omega), Eq(k, -I*omega)), (-I*x*exp(I*omega*x)*sin(omega*x)/2 + x*exp(I*omega*x)*cos(omega*x)/2 + exp(I*omega*x)*sin(omega*x)/(2*omega), Eq(k, I*omega)), (k*exp(k*x)*cos(omega*x)/(k**2 + omega**2) + omega*exp(k*x)*sin(omega*x)/(k**2 + omega**2), True))

# %%
expr.integrate(x)
# Out:
# Piecewise((x, Eq(k, 0) & Eq(omega, 0)), (I*x*exp(-I*omega*x)*sin(omega*x)/2 + x*exp(-I*omega*x)*cos(omega*x)/2 + exp(-I*omega*x)*sin(omega*x)/(2*omega), Eq(k, -I*omega)), (-I*x*exp(I*omega*x)*sin(omega*x)/2 + x*exp(I*omega*x)*cos(omega*x)/2 + exp(I*omega*x)*sin(omega*x)/(2*omega), Eq(k, I*omega)), (k*exp(k*x)*cos(omega*x)/(k**2 + omega**2) + omega*exp(k*x)*sin(omega*x)/(k**2 + omega**2), True))

# %%
y=Symbol('y')

# %%
expr=exp(-(x**2+y**2))

# %%
expr.diff(x)
# Out:
# -2*x*exp(-x**2 - y**2)

# %%
expr= y+ (y+tan(x+y)* y.diff(x))

# %%
f=Function('f')

# %%
expr= f(x) + ((f(x) +tan(x+ f(x)))* f(x).diff(x))

# %%
dsolve(expr)
# Out:
# Eq(f(x), C1 - C1*x/(C1 + tan(C1)) + C1*x**2*(C1*(-tan(C1)**2 - 2)/(C1 + tan(C1)) + tan(C1)**2 + 2)/(2*(C1 + tan(C1))**2) + C1*x**3*(2*(tan(C1)**2 + 1)*tan(C1) - (-C1*(-tan(C1)**2 - 2)/(C1 + tan(C1)) - 1)*(-tan(C1)**2 - 1)/(C1 + tan(C1)) - 2*(-tan(C1)**2 - 1)**2/(C1 + tan(C1)) - (2*C1*(tan(C1)**2 + 1)*tan(C1) - 2*C1*(-tan(C1)**2 - 2)*(-tan(C1)**2 - 1)/(C1 + tan(C1)) + tan(C1)**2 + 1)/(C1 + tan(C1)) - (2*C1*(tan(C1)**2 + 1)*tan(C1) - C1*(-C1*(-tan(C1)**2 - 2)/(C1 + tan(C1)) - 1)*(-tan(C1)**2 - 2)/(C1 + tan(C1)) - 2*C1*(-tan(C1)**2 - 2)*(-tan(C1)**2 - 1)/(C1 + tan(C1)) + C1*(-tan(C1)**2 - 2)/(C1 + tan(C1)) - 2*C1*(C1*(tan(C1)**2 + 1)*tan(C1) - C1*(-tan(C1)**2 - 2)**2/(C1 + tan(C1)) + tan(C1)**2 + 2)/(C1 + tan(C1)) + tan(C1)**2 + 2)/(C1 + tan(C1)))/(6*(C1 + tan(C1))**2) + C1*x**4*(2*(tan(C1)**2 + 1)**2 + 4*(tan(C1)**2 + 1)*tan(C1)**2 + 2*(-C1*(-tan(C1)**2 - 2)/(C1 + tan(C1)) - 1)*(tan(C1)**2 + 1)*tan(C1)/(C1 + tan(C1)) + 12*(-tan(C1)**2 - 1)*(tan(C1)**2 + 1)*tan(C1)/(C1 + tan(C1)) - 2*(C
# ...

# %%
# Out:
#   File "<ipython-input-33-a936aa995a2e>", line 1
#     expr= (cos(x+f(x))* f(x)) + (cos(x+f(x))*((f(x) +tan(x+ f(x)))* f(x).diff(x))
#                                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
expr= (cos(x+f(x))* f(x)) + (cos(x+f(x))*((f(x) +tan(x+ f(x)))* f(x).dif\

# %%
dsolve(expr,f(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8699677212e7> in <module>
# ----> 1 dsolve(expr,f(x))
#
# NameError: name 'dsolve' is not defined
